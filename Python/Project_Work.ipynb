# %% [markdown]
# # Implementazione di un algoritmo di previsione delle serie storiche

# %% [markdown]
# Importiamo le librerie necessarie per svolgere il progetto

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Acquisiamo i dati in input

# %%
df = pd.read_csv("https://raw.githubusercontent.com/iantomasinicola/17dicembre/refs/heads/main/Dati%20input/Forecast_ets_example.csv",
            skiprows = 2,
            sep = ";")

# %% [markdown]
# Visualizziamo le prime 5 righe

# %%
df.head(5)
# Out:
#          Date  Airport Passengers
# 0  2009-01-01             2644539
# 1  2009-02-01             2359800
# 2  2009-03-01             2925918
# 3  2009-04-01             3024973
# 4  2009-05-01             3177100

# %% [markdown]
# Modifico le impostazioni di visualizzazione dei dati su pandas

# %%
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# Creo le medie mobili centrate

# %%
df["Media_mobile_centrata"] = df["Airport Passengers"].rolling(window=12,center=True).mean()
df.head(12)
# Out:
#           Date  Airport Passengers  Media_mobile_centrata
# 0   2009-01-01             2644539                    NaN
# 1   2009-02-01             2359800                    NaN
# 2   2009-03-01             2925918                    NaN
# 3   2009-04-01             3024973                    NaN
# 4   2009-05-01             3177100                    NaN
# 5   2009-06-01             3419595                    NaN
# 6   2009-07-01             3649702                3111578
# 7   2009-08-01             3650668                3123322
# 8   2009-09-01             3191526                3136286
# 9   2009-10-01             3249428                3151289
# 10  2009-11-01             2971484                3160796
# 11  2009-12-01             3074209                3177734

# %% [markdown]
# Calcolo la componente di stagionalità e casualità

# %%
df["stagionalita_casualita"] = df["Airport Passengers"]-df["Media_mobile_centrata"]
df.head(12)
# Out:
#           Date  Airport Passengers  Media_mobile_centrata  \
# 0   2009-01-01             2644539                    NaN
# 1   2009-02-01             2359800                    NaN
# 2   2009-03-01             2925918                    NaN
# 3   2009-04-01             3024973                    NaN
# 4   2009-05-01             3177100                    NaN
# 5   2009-06-01             3419595                    NaN
# 6   2009-07-01             3649702                3111578
# 7   2009-08-01             3650668                3123322
# 8   2009-09-01             3191526                3136286
# 9   2009-10-01             3249428                3151289
# 10  2009-11-01             2971484                3160796
# 11  2009-12-01             3074209                3177734
#
#     stagionalita_casualita
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                   538124
# 7                   527346
# 8                    55240
# 9                    98139
# 10                 -189312
# 11                 -103525

# %% [markdown]
# Converto la colonna Data nel tipo date

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %% [markdown]
# Creo una colonna che estrapola il mese della data

# %%
df["mese"]=df["Date"].dt.month
df.head(12)
# Out:
#          Date  Airport Passengers  Media_mobile_centrata  \
# 0  2009-01-01             2644539                    NaN
# 1  2009-02-01             2359800                    NaN
# 2  2009-03-01             2925918                    NaN
# 3  2009-04-01             3024973                    NaN
# 4  2009-05-01             3177100                    NaN
# 5  2009-06-01             3419595                    NaN
# 6  2009-07-01             3649702                3111578
# 7  2009-08-01             3650668                3123322
# 8  2009-09-01             3191526                3136286
# 9  2009-10-01             3249428                3151289
# 10 2009-11-01             2971484                3160796
# 11 2009-12-01             3074209                3177734
#
#     stagionalita_casualita  mese
# 0                      NaN     1
# 1                      NaN     2
# 2                      NaN     3
# 3                      NaN     4
# 4                      NaN     5
# 5                      NaN     6
# 6                   538124     7
# 7                   527346     8
# 8                    55240     9
# 9                    98139    10
# 10                 -189312    11
# 11                 -103525    12

# %% [markdown]
# Calcolo le stagionalità

# %%
df_stagionalita = df.groupby(by="mese",
           as_index=False, 
           dropna=False)["stagionalita_casualita"].mean().rename(columns={"stagionalita_casualita":"stagionalita"})
df_stagionalita
# Out:
#     mese  stagionalita
# 0      1       -433144
# 1      2       -692841
# 2      3       -154764
# 3      4       -115615
# 4      5        146648
# 5      6        378445
# 6      7        535543
# 7      8        539138
# 8      9         85406
# 9     10        135183
# 10    11       -188401
# 11    12       -157856

# %% [markdown]
# Combino i due dataframe

# %%
df = pd.merge(df, df_stagionalita, on = "mese")
df.head(12)
# Out:
#          Date  Airport Passengers  Media_mobile_centrata  \
# 0  2009-01-01             2644539                    NaN
# 1  2009-02-01             2359800                    NaN
# 2  2009-03-01             2925918                    NaN
# 3  2009-04-01             3024973                    NaN
# 4  2009-05-01             3177100                    NaN
# 5  2009-06-01             3419595                    NaN
# 6  2009-07-01             3649702                3111578
# 7  2009-08-01             3650668                3123322
# 8  2009-09-01             3191526                3136286
# 9  2009-10-01             3249428                3151289
# 10 2009-11-01             2971484                3160796
# 11 2009-12-01             3074209                3177734
#
#     stagionalita_casualita  mese  stagionalita
# 0                      NaN     1       -433144
# 1                      NaN     2       -692841
# 2                      NaN     3       -154764
# 3                      NaN     4       -115615
# 4                      NaN     5        146648
# 5                      NaN     6        378445
# 6                   538124     7        535543
# 7                   527346     8        539138
# 8                    55240     9         85406
# 9                    98139    10        135183
# 10                 -189312    11       -188401
# 11                 -103525    12       -157856

# %% [markdown]
# Calcoliamo i passeggeri destagionalizzati

# %%
df["passeggeri_destagionalizzati"] = df["Airport Passengers"]-df["stagionalita"]

# %% [markdown]
# Trasformo l'indice in una colonna

# %%
df = df.reset_index(names="Id")
df.head(12)
# Out:
#     Id       Date  Airport Passengers  Media_mobile_centrata  \
# 0    0 2009-01-01             2644539                    NaN
# 1    1 2009-02-01             2359800                    NaN
# 2    2 2009-03-01             2925918                    NaN
# 3    3 2009-04-01             3024973                    NaN
# 4    4 2009-05-01             3177100                    NaN
# 5    5 2009-06-01             3419595                    NaN
# 6    6 2009-07-01             3649702                3111578
# 7    7 2009-08-01             3650668                3123322
# 8    8 2009-09-01             3191526                3136286
# 9    9 2009-10-01             3249428                3151289
# 10  10 2009-11-01             2971484                3160796
# 11  11 2009-12-01             3074209                3177734
#
#     stagionalita_casualita  mese  stagionalita  passeggeri_destagionalizzati
# 0                      NaN     1       -433144                       3077683
# 1                      NaN     2       -692841                       3052641
# 2                      NaN     3       -154764                       3080682
# 3                      NaN     4       -115615                       3140588
# 4                      NaN     5        146648                       3030452
# 5                      NaN     6        378445                       3041150
# 6                   538124     7        535543                       3114159
# 7                   527346     8        539138                       3111530
# 8                    55240     9         85406                       3106120
# 9                    98139    10        135183                       3114245
# 10                 -189312    11       -188401                       3159885
# 11                 -103525    12       -157856                       3232065

# %% [markdown]
# Calcolo la retta di regressione

# %%
m, q = np.polyfit(df.query("passeggeri_destagionalizzati.notna()")["Id"], 
                  df.query("passeggeri_destagionalizzati.notna()")["passeggeri_destagionalizzati"], 
                  1)
print(m,q)
# Out:
# 14292.583169939895 3022157.5068898285

# %% [markdown]
# Calcolo il trend

# %%
df["Trend"]= df["Id"]*m + q 
df.head(5)
# Out:
#    Id       Date  Airport Passengers  Media_mobile_centrata  \
# 0   0 2009-01-01             2644539                    NaN
# 1   1 2009-02-01             2359800                    NaN
# 2   2 2009-03-01             2925918                    NaN
# 3   3 2009-04-01             3024973                    NaN
# 4   4 2009-05-01             3177100                    NaN
#
#    stagionalita_casualita  mese  stagionalita  passeggeri_destagionalizzati  \
# 0                     NaN     1       -433144                       3077683
# 1                     NaN     2       -692841                       3052641
# 2                     NaN     3       -154764                       3080682
# 3                     NaN     4       -115615                       3140588
# 4                     NaN     5        146648                       3030452
#
#     Trend
# 0 3022158
# 1 3036450
# 2 3050743
# 3 3065035
# 4 3079328

# %% [markdown]
# Calcolo delle previsioni

# %%
df["previsione"]=df["Trend"]+df["stagionalita"]
df.head(12)
# Out:
#     Id       Date  Airport Passengers  Media_mobile_centrata  \
# 0    0 2009-01-01             2644539                    NaN
# 1    1 2009-02-01             2359800                    NaN
# 2    2 2009-03-01             2925918                    NaN
# 3    3 2009-04-01             3024973                    NaN
# 4    4 2009-05-01             3177100                    NaN
# 5    5 2009-06-01             3419595                    NaN
# 6    6 2009-07-01             3649702                3111578
# 7    7 2009-08-01             3650668                3123322
# 8    8 2009-09-01             3191526                3136286
# 9    9 2009-10-01             3249428                3151289
# 10  10 2009-11-01             2971484                3160796
# 11  11 2009-12-01             3074209                3177734
#
#     stagionalita_casualita  mese  stagionalita  passeggeri_destagionalizzati  \
# 0                      NaN     1       -433144                       3077683
# 1                      NaN     2       -692841                       3052641
# 2                      NaN     3       -154764                       3080682
# 3                      NaN     4       -115615                       3140588
# 4                      NaN     5        146648                       3030452
# 5                      NaN     6        378445                       3041150
# 6                   538124     7        535543                       3114159
# 7                   527346     8        539138                       3111530
# 8                    55240     9         85406                       3106120
# 9                    98139    10        135183                       3114245
# 10                 -189312    11       -188401                       3159885
# 11                 -103525    12       -157856                       3232065
#
#      Trend  previsione
# 0  3022158     2589013
# 1  3036450     2343609
# 2  3050743     2895979
# 3  3065035     2949420
# 4  3079328     3225975
# 5  3093620     3472065
# 6  3107913     3643456
# 7  3122206     3661343
# 8  3136498     3221904
# 9  3150791     3285974
# 10 3165083     2976682
# 11 3179376     3021520

# %% [markdown]
# Visualizzo le previsioni

# %%
df.query("`Airport Passengers`.isna()")[["Date","previsione"]]
# Out:
#          Date  previsione
# 57 2013-10-01     3972018
# 58 2013-11-01     3662726
# 59 2013-12-01     3707564
# 60 2014-01-01     3446568
# 61 2014-02-01     3201164
# 62 2014-03-01     3753534
